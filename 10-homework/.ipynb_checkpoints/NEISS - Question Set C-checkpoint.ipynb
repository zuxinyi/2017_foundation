# %% [markdown]
# # Exercise: NEISS, Question Set C
#
# #### Summary
#
# The [National Electronic Injury Surveillance System](https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS) is a data product produced by the US Consumer Product Safety Commission. It tracks emergency room injuries related to consumer products (e.g., "a door fell on me!").
#
# #### Files
#
# - **nss15.tsv**: injury data (one injury per row)
# - **2017NEISSCodingManualCPSConlyNontrauma.pdf**: column definitions and explanations
# - **2015 Neiss data highlights.pdf**: a partial summary of the data
# - **2017ComparabilityTable.pdf**: product code definitions
# - **categories-cleaned.txt**: product code definitions in CSV format (great for joining!)
#
# #### Source
#
# https://www.cpsc.gov/Safety-Education/Safety-Guides/General-Information/National-Electronic-Injury-Surveillance-System-NEISS
#
# #### Skills
#
# - Reading tab-separated files
# - Ignoring bad lines
# - Replacing values
# - Using numpy/`np.nan`
# - String search using regular expressions
# - Averages practice
# - Converting `.value_counts()` and similar results into DataFrames

# %% [markdown]
# # Read in `nss15.tsv`
#
# Some of the lines just **aren't formatted correctly**. Maybe we can avoid those?

# %%
import pandas as pd
df = pd.read_csv('nss15.tsv', sep='\t',error_bad_lines= False)
df.head()
# Out:
# b'Skipping line 10822: expected 19 fields, saw 20\n'
# b'Skipping line 48623: expected 19 fields, saw 20\nSkipping line 62534: expected 19 fields, saw 20\n'
# b'Skipping line 103739: expected 19 fields, saw 20\n'
# b'Skipping line 135495: expected 19 fields, saw 20\nSkipping line 151678: expected 19 fields, saw 20\n'
# b'Skipping line 237135: expected 19 fields, saw 20\nSkipping line 240597: expected 19 fields, saw 20\n'
# b'Skipping line 274270: expected 19 fields, saw 20\nSkipping line 277461: expected 19 fields, saw 20\n'
#    CPSC Case #   trmt_date  psu   weight stratum  age  sex  race race_other  \
# 0    150733174  07/11/2015   38  15.7762       V    5    1     0        NaN
# 1    150734723  07/06/2015   43  83.2157       S   36    1     1        NaN
# 2    150817487  08/02/2015   51  74.8813       L   20    2     0        NaN
# 3    150717776  06/26/2015   41  15.7762       V   61    1     0        NaN
# 4    150721694  07/04/2015   42  74.8813       L   88    2     3   HISPANIC
#
#    diag      diag_other  body_part  disposition  location  fmv  prod1   prod2  \
# 0    57             NaN         33            1         9    0   1267     NaN
# 1    57             NaN         34            1         1    0   1439  4057.0
# 2    71  OTITIS EXTERNA         94            1         0    0   3274     NaN
# 3    71            PAIN         35            1         0    0    611     NaN
# 4    62             NaN         75            1         0    0   1893  1807.0
#
#                                                narr1  \
# 0  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
#
#                                                narr2
# 0                                               X IT
# 1  AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2  T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                NaN
# 4           DOOR AND FELL.DENIES LOC. DX HEAD INJURY

# %% [markdown]
# ### Check that your dataframe has 357727 rows and 19 columns.

# %%
df.shape
# Out:
# (357727, 19)

# %% [markdown]
# ### List the columns and their data types

# %%
df.dtypes
# Out:
# CPSC Case #      int64
# trmt_date       object
# psu              int64
# weight         float64
# stratum         object
# age              int64
# sex              int64
# race             int64
# race_other      object
# diag             int64
# diag_other      object
# body_part        int64
# disposition      int64
# location         int64
# fmv              int64
# prod1            int64
# prod2          float64
# narr1           object
# narr2           object
# dtype: object

# %% [markdown]
# ### What does each column mean?

# %%
#data dictionary

# %% [markdown]
# # Cleaning up a column
#
# Take a look at the **sex** column. How many rows of each sex are there?

# %%
df['sex'].value_counts()
# Out:
# 1    195071
# 2    162654
# 0         2
# Name: sex, dtype: int64

# %% [markdown]
# ## Replace the numbers with the appropriate words they stand for.
#
# Those numbers are terrible - codes are fine for storage but not really for reading. **Replace the numbers with the  words they stand for.**
#
# Refer to page 7 of the column definitions file.

# %%
df.sex[df.sex == 1] = 'Male' 
df.sex[df.sex == 2]   = 'Female'
df.sex[df.sex == 0]   = 'Not recorded'
df

#df.sex.replace(1, 'Male', inplace = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#         CPSC Case #   trmt_date  psu   weight stratum  age     sex  race  \
# 0         150733174  07/11/2015   38  15.7762       V    5    Male     0
# 1         150734723  07/06/2015   43  83.2157       S   36    Male     1
# 2         150817487  08/02/2015   51  74.8813       L   20  Female     0
# 3         150717776  06/26/2015   41  15.7762       V   61    Male     0
# 4         150721694  07/04/2015   42  74.8813       L   88  Female     3
# 5         150721815  07/02/2015   32   5.6748       C  216  Female     1
# 6         150713483  06/08/2015   93  15.7762       V   25    Male     2
# 7         150704114  06/14/2015   56  83.2157       S   53    Male     1
# 8         150736558  07/16/2015   70  83.2157       S   98    Male     2
# 9         150734928  07/13/2015   51  74.8813       L   48  Female     2
# 10        150734952  07/04/2015   57  15.7762       V   20    Male     2
# 11        150821622  07/20/2015   43  83.2157       S   20  Female     1
# 12        150713631  07/04/2015   67  15.7762       V   11    Male     0
# 13        150666343  06/27/2015   95  15.7762       V   26  Female     1
# 14        150748843  07/16/2015    5  37.6645       L   33    Male     4
# 15        150655986  06/06/2015   96  83.2157       S   36    Male     0
# 16        150901411  08/27/2015    4  83.2157       S   65  Female     1
# 17        150844598  07/26/2015    8   5.6748       C    2    Male     2
# 18        150960076  09/19/2015   95  15.7762       V   69  Female     1
# 19        150970927  09/26/2015   24  97.9239       M  204  Female     1
# 20        150942430  09/09/2015   95  15.7762       V   47  Female     1
# 21        150956275  09/07/2015   68  97.9239       M   16    Male     1
# 22        150944645  09/14/2015   58  15.7762       V   31    Male     0
# 23        151028950  09/05/2015   77  15.7762       V    7    Male     0
# 24        151029050  09/05/2015   14  49.2646       M   27  Female     0
# 25        151005625  09/28/2015   51  74.8813       L  209  Female     1
# 26        151005691  09/29/2015   51  74.8813       L   27  Female     2
# 27        150913230  09/04/2015    2  15.7762       V   39    Male     0
# 28        150964576  09/19/2015   37   5.6748       C  207    Male     0
# 29        150971068  09/22/2015   42  74.8813       L   14    Male     1
# ...             ...         ...  ...      ...     ...  ...     ...   ...
# 357697    150603931  05/19/2015   67  15.0591       V    4    Male     0
# 357698    150725804  07/08/2015   78  97.9239       M   33  Female     2
# 357699    150702215  06/27/2015   21  15.7762       V   51  Female     0
# 357700    151124313  11/01/2015   79  85.7374       S    3    Male     1
# 357701    151124428  11/02/2015   68  97.9239       M   21  Female     1
# 357702    151115064  11/04/2015   73  85.7374       S   12  Female     0
# 357703    151100368  10/28/2015   73  83.2157       S   85  Female     0
# 357704    150639249  06/08/2015   33  15.7762       V    4    Male     1
# 357705    150639257  06/08/2015   33  15.7762       V    5  Female     1
# 357706    150630000  05/20/2015   16  97.9239       M    5  Female     2
# 357707    150528367  01/13/2015   14  49.2646       M   85  Female     0
# 357708    150528459  05/12/2015   21  15.0591       V   12  Female     0
# 357709    150619154  05/13/2015   26  15.0591       V   27    Male     3
# 357710    150554802  05/15/2015   31   5.6748       C   15    Male     2
# 357711    150643117  05/31/2015   90   5.6748       C  201    Male     1
# 357712    150607827  05/27/2015   32   5.6748       C  218    Male     1
# 357713    150600190  05/28/2015   73  80.8381       S    5    Male     0
# 357714    150648619  06/17/2015   95  15.7762       V   52  Female     1
# 357715    150640832  06/08/2015   67  15.7762       V    8  Female     0
# 357716    150633445  05/31/2015   50  74.8813       L  220  Female     0
# 357717    150633526  04/04/2015   14  49.2646       M   51  Female     0
# 357718    150628863  06/08/2015   95  15.7762       V   30  Female     1
# 357719    150607637  05/22/2015   32   5.6748       C  215  Female     2
# 357720    150747209  07/24/2015   73  83.2157       S   14  Female     0
# 357721    150747217  07/24/2015   73  83.2157       S    2    Male     0
# 357722    150739278  05/31/2015   23  15.0591       V    7    Male     0
# 357723    150733393  07/11/2015   18   5.6748       C    3  Female     2
# 357724    150819286  07/24/2015   21  15.7762       V   38    Male     0
# 357725    150823002  08/08/2015   78  97.9239       M   38  Female     1
# 357726    150723074  06/20/2015   54  49.2646       M    5  Female     1
#
#        race_other  diag        diag_other  body_part  disposition  location  \
# 0             NaN    57               NaN         33            1         9
# 1             NaN    57               NaN         34            1         1
# 2             NaN    71    OTITIS EXTERNA         94            1         0
# 3             NaN    71              PAIN         35            1         0
# 4        HISPANIC    62               NaN         75            1         0
# 5             NaN    71  DOG SCRATCH/BITE         76            1         1
# 6             NaN    51               NaN         33            4         9
# 7             NaN    57               NaN         30            1         0
# 8             NaN    59               NaN         76            1         1
# 9             NaN    53               NaN         79            1         5
# 10            NaN    59               NaN         82            1         1
# 11            NaN    57               NaN         36            1         9
# 12            NaN    60               NaN         88            1         0
# 13            NaN    62               NaN         75            1         1
# 14            NaN    53               NaN         93            1         1
# 15            NaN    59               NaN         82            1         0
# 16            NaN    59               NaN         83            1         1
# 17            NaN    57               NaN         92            1         1
# 18            NaN    64               NaN         79            1         1
# 19            NaN    59               NaN         76            1         1
# 20            NaN    64               NaN         79            1         0
# 21            NaN    59               NaN         35            4         1
# 22            NaN    58               NaN         75            1         0
# 23            NaN    57               NaN         34            1         0
# 24            NaN    58               NaN         76            1         1
# 25            NaN    58               NaN         75            1         0
# 26            NaN    64               NaN         93            1         0
# 27            NaN    71            OTITIS         94            1         0
# 28            NaN    62               NaN         75            4         1
# 29            NaN    64               NaN         31            1         0
# ...           ...   ...               ...        ...          ...       ...
# 357697        NaN    60               NaN         88            1         9
# 357698        NaN    71              PAIN         94            1         0
# 357699        NaN    53               NaN         83            1         1
# 357700        NaN    59               NaN         88            1         1
# 357701        NaN    64               NaN         79            1         1
# 357702        NaN    64               NaN         37            1         9
# 357703        NaN    57               NaN         80            4         1
# 357704        NaN    59               NaN         75            1         1
# 357705        NaN    57               NaN         76            2         0
# 357706        NaN    59               NaN         94            1         1
# 357707        NaN    57               NaN         79            5         1
# 357708        NaN    59               NaN         92            1         1
# 357709   HISPANIC    59               NaN         33            1         1
# 357710        NaN    64               NaN         37            1         9
# 357711        NaN    62               NaN         75            1         1
# 357712        NaN    71              LIMP         36            1         1
# 357713        NaN    56               NaN         94            1         0
# 357714        NaN    64               NaN         30            1         1
# 357715        NaN    64               NaN         32            1         0
# 357716        NaN    68               NaN         85            1         0
# 357717        NaN    56               NaN         92            1         1
# 357718        NaN    64               NaN         79            1         1
# 357719        NaN    59               NaN         94            1         0
# 357720        NaN    62               NaN         75            1         5
# 357721        NaN    62               NaN         75            1         1
# 357722        NaN    59               NaN         76            1         1
# 357723        NaN    68               NaN         85            1         0
# 357724        NaN    71              PAIN         79            1         0
# 357725        NaN    59               NaN         82            1         1
# 357726        NaN    57               NaN         34            1         9
#
#         fmv  prod1   prod2                                              narr1  \
# 0         0   1267     NaN  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1         0   1439  4057.0  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2         0   3274     NaN  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3         0    611     NaN  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4         0   1893  1807.0  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
# 5         0   1715     NaN  16 MOF AT HOME PULLED FAMILY DOG-HUSKIES COLLA...
# 6         3   1138     NaN  25 YOM WAS CAMPING WHEN FRIEND THREW A PRESSUR...
# 7         0   5040     NaN  53 YOM BIKE WRECK SUNDAY PAIN CHEST SHOULDER &...
# 8         0   1807     NaN          98 Y/O M FELL IN FLOOR AND LACERATED FACE
# 9         0   4057  1807.0  48 YO F, C/O RT FLANK PAIN 6 DAYS S/P FALL WAS...
# 10        0   1894     NaN  20 YOM DX HAND LACERATION - S/P PT PUNCHED A W...
# 11        0   1267     NaN  L DISTAL FIB FX/20YOWF WHILE PLAYING SOCCER AT...
# 12        0   3274  1284.0  DX LOSS TEETH D/T TRAUME: 11YOM LOOSE LOWER R ...
# 13        0   1807     NaN  CHI,LEFT WRIST SPRAIN.26YOF SLIPPED AND FELL O...
# 14        0   4057     NaN     33 YOM SMASHED FOOT INTO COFFEE TABLE LAST PM.
# 15        0    894     NaN                     36 YOM CUT HAND WITH A HACKSAW
# 16        0   1817     NaN  65 YO WF CUT FOOT WHEN BARE FOOTED ON PORCH AT...
# 17        0    380     NaN  2YOM INJURED FINGER BY PUTTING IT IN A HOUSE F...
# 18        0   4014     NaN  LUMBAR STRIAN. 69 YOF STRAINED HER LOWER BACK ...
# 19        0    474     NaN          4 M/.O F   BROTHER  DROPPED  CUP  ON FACE
# 20        0    676     NaN  LUMBAR STR.  47YOF STRAINED LOWER BACK RIPPING...
# 21        0   5036     NaN  16 YOM TRIED TO DO A WHEELIE ON HIS DIRT BIKE ...
# 22        0   1239     NaN  31 YOM WAS THROWN FROM A HORSE INTO A TREE AND...
# 23        0   1329     NaN   7YOM SUST WRIST FX WHEN HE FELL OFF HIS SCOOTER*
# 24        0    611     NaN  27YOF H'TOMA F'HEAD - SYNCOPE, FELL GETTING OU...
# 25        0    679  1807.0  9 MO F AT 11:30AM TODAY FELL APPROX 2 FT FT BA...
# 26        0   1884     NaN  27 YO F C/O LT 5TH TOE PAIN REPORTS STUBBING T...
# 27        0   3274     NaN  39YOM DOING ALOT OF SWIMMING AND NOW EARS HURT...
# 28        0   4076     NaN  7 MONTH M WITH CHI HIT HEAD, FELL FROM BED - A...
# 29        0   1211     NaN  14YOM PAIN TO BACK AND HEAD WHEN PLAYING FOOTB...
# ...     ...    ...     ...                                                ...
# 357697    0   5017     NaN  DX DENTAL INJ 4YOM PATIENT WAS STRUCK IN HIS M...
# 357698    0   1616     NaN  33 YOF INJURED EAR WEARING EARRINGS 2 DAYS AGO...
# 357699    0   1426     NaN  51YF ACC STRUCK FOOT C AN AXE HANDLE WHILE HEL...
# 357700    0   4076     NaN     3YOM JUMPED OFF OF BED HIT MOUTH HAS A LIP LAC
# 357701    0   4014     NaN  21 YOF C/O LOW BACK PAIN AFTER HELPING MOVE HE...
# 357702    0   1233     NaN  12YOF JUMPING ON A TRAMPOLINE AT *** AND STRAI...
# 357703    0   1807     NaN  85YOF FELL TO HER BATHROOM FLOOR AND FRACTURED...
# 357704    0   3262     NaN         4 YOM FELL OFF POOL LADDER  DX:  SCALP LAC
# 357705    0   3286     NaN  5 YOF 4 WHEELERS ACCIDENT, EJECTED D X:  MULTI...
# 357706    0   1871     NaN  5 YOF MOTHER STATES CHILD RAN INTO A FENCE AT ...
# 357707    0    676  1884.0                85YOF FX HIP- TRIPPED RUG, HIT WALL
# 357708    0    464     NaN  12YF ACC CUT FINGER ON A KNIFE CUTTING ICECREA...
# 357709    0    836     NaN          27 YOM LAC TO ARM WHEN USING A BOX CUTTER
# 357710    0   1205     NaN    15 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN
# 357711    0   4076  1807.0  1MOM-PT & 5YOLD SIBLING WERE LAYING ON THE BED...
# 357712    0   1807     NaN  18 MOM PLAYING WITH BROTHER THIS A.M. AND FELL...
# 357713    0   1936     NaN                  5YOM PUT A BB IN RIGHT EAR FB EAR
# 357714    0   1842     NaN  RT SHOULDER STR.  52YOF FELL GOING DOWN A FLIG...
# 357715    0   3216     NaN  DX ELBOW STRAIN R: 8YOF FELL YTDY W ROLLER SKA...
# 357716    0   1913     NaN  20 MOF TOXIC INGESTION, MOM REPORTS WITNESSING...
# 357717    0   1616     NaN                  51YOF F'BDY- RING STUCK ON FINGER
# 357718    0   1522     NaN  LUMBAR STRAIN. 30 YOF STRAINED HER LOWER BACK ...
# 357719    0   1616     NaN  15 MOF R EARRING WAS PULLED OUT OF EAR RESULTI...
# 357720    0   1807     NaN  14YOF AT THE HOSPITAL WAS WITNESSING HER SISTE...
# 357721    0   1301     NaN  2YOM FELL OFF HIS TRICYCLE TO THE DRIVEWAY ONT...
# 357722    0   1864     NaN  7 YO MALE HIT CORNER OF COUNTER WHILE PLAYING....
# 357723    0   1931     NaN     3 YOF INGESTED 60 VITAMIN ***.  DX: INGESTION.
# 357724    0   3250     NaN  38YM C/O WORSENING LBP THAT STARTED WHILE LIFT...
# 357725    0    464     NaN  38 YOF INJURED HAND, CUT WITH BREAD KNIFE AT H...
# 357726    0   3273     NaN  5YOF ON A PLAYGROUND & FELL OFF PLAY STRUCTURE...
#
#                                                     narr2
# 0                                                    X IT
# 1       AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2       T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                     NaN
# 4                DOOR AND FELL.DENIES LOC. DX HEAD INJURY
# 5       ND SCRAPING TEETH ON PTS FACE, NOT A TRUE BITE...
# 6       WHICH FLASHED. FD NS. DX:  BURNS L UPPER & LOW...
# 7                                                     NaN
# 8                                                     NaN
# 9       ABLE WHICH HIT THE FLOOR STRIKING RT FLANK DX ...
# 10                                                    NaN
# 11                       LE CAUSING INJURY TO DISTAL FIB.
# 12                      M OF POOL KNOCKING HIS TOOTH LOSE
# 13                                                    NaN
# 14                   DX:  L TOE CONT, SUBUNGUAL HEMATOMA.
# 15                                   DX:  HAND LACERATION
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                              LAC  FACE
# 20                                                    NaN
# 21      IKE. DX LACERATION. DEEP DIRTY WOUND LEFT KNEE...
# 22                                     DX  SCALP HEMATOMA
# 23                                                    NaN
# 24                                                    NaN
# 25                RDWOOD FLOOR CRIED DX PARIETAL HEMATOMA
# 26                                        L DX TOE SPRAIN
# 27                                                    NaN
# 28                                                    NaN
# 29                    OTHER PLAYER. +DAZED. / BACK STRAIN
# ...                                                   ...
# 357697                                                NaN
# 357698                                                NaN
# 357699                                            >>CONTS
# 357700                                                NaN
# 357701                      ME. DX LOW BACK SPRAIN STRAIN
# 357702                                                NaN
# 357703                                                NaN
# 357704                                                NaN
# 357705                                                NaN
# 357706                         DX LACERATION TO RIGHT EAR
# 357707                                                NaN
# 357708                                              >>LAC
# 357709                                                NaN
# 357710                                                NaN
# 357711  FELL OFF BED ONTO THE FLOOR CRYING HIT HEAD. D...
# 357712                         BEEN LIMPING SINCE DX LIMP
# 357713                                                NaN
# 357714                                          SHOULDER.
# 357715                             O R ELBOW AND WRIST PN
# 357716  IR GEL THEN PUT THE GEL IN HER MOUTH, BEGAN VO...
# 357717                                                NaN
# 357718                       STRAP A CHILD IN A STROLLER.
# 357719                                     TO BACK OF EAR
# 357720  PASSED OUT TO THE FLOOR ONTO HEAD CLOSED HEAD ...
# 357721                                                NaN
# 357722                                                NaN
# 357723                                                NaN
# 357724                                              >>LBP
# 357725                                         LACERATION
# 357726         +PAIN TO RT WRIST & FOREARM.  DX; WRIST FX
#
# [357727 rows x 19 columns]

# %% [markdown]
# ## Confirm you have 195071 male, 162654 female, and 2 "Not Recorded."

# %%
df['sex'].value_counts()
# Out:
# Male            195071
# Female          162654
# Not recorded         2
# Name: sex, dtype: int64

# %% [markdown]
# ## Graph the number of men and women, but don’t included the “Not Recorded” records

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df[(df.sex == 'Male') | (df.sex == 'Female')].sex.value_counts().plot(kind = 'barh')

# %% [markdown]
# ## "Not recorded" seems silly - change it to be `NaN` instead
#
# Don't use `na_values` for this.

# %%
import numpy as np   #the concept of empty
df.sex.replace('Not recorded', np.nan, inplace = True)
df
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  age     sex  race  \
# 0         150733174  07/11/2015   38  15.7762       V    5    Male     0
# 1         150734723  07/06/2015   43  83.2157       S   36    Male     1
# 2         150817487  08/02/2015   51  74.8813       L   20  Female     0
# 3         150717776  06/26/2015   41  15.7762       V   61    Male     0
# 4         150721694  07/04/2015   42  74.8813       L   88  Female     3
# 5         150721815  07/02/2015   32   5.6748       C  216  Female     1
# 6         150713483  06/08/2015   93  15.7762       V   25    Male     2
# 7         150704114  06/14/2015   56  83.2157       S   53    Male     1
# 8         150736558  07/16/2015   70  83.2157       S   98    Male     2
# 9         150734928  07/13/2015   51  74.8813       L   48  Female     2
# 10        150734952  07/04/2015   57  15.7762       V   20    Male     2
# 11        150821622  07/20/2015   43  83.2157       S   20  Female     1
# 12        150713631  07/04/2015   67  15.7762       V   11    Male     0
# 13        150666343  06/27/2015   95  15.7762       V   26  Female     1
# 14        150748843  07/16/2015    5  37.6645       L   33    Male     4
# 15        150655986  06/06/2015   96  83.2157       S   36    Male     0
# 16        150901411  08/27/2015    4  83.2157       S   65  Female     1
# 17        150844598  07/26/2015    8   5.6748       C    2    Male     2
# 18        150960076  09/19/2015   95  15.7762       V   69  Female     1
# 19        150970927  09/26/2015   24  97.9239       M  204  Female     1
# 20        150942430  09/09/2015   95  15.7762       V   47  Female     1
# 21        150956275  09/07/2015   68  97.9239       M   16    Male     1
# 22        150944645  09/14/2015   58  15.7762       V   31    Male     0
# 23        151028950  09/05/2015   77  15.7762       V    7    Male     0
# 24        151029050  09/05/2015   14  49.2646       M   27  Female     0
# 25        151005625  09/28/2015   51  74.8813       L  209  Female     1
# 26        151005691  09/29/2015   51  74.8813       L   27  Female     2
# 27        150913230  09/04/2015    2  15.7762       V   39    Male     0
# 28        150964576  09/19/2015   37   5.6748       C  207    Male     0
# 29        150971068  09/22/2015   42  74.8813       L   14    Male     1
# ...             ...         ...  ...      ...     ...  ...     ...   ...
# 357697    150603931  05/19/2015   67  15.0591       V    4    Male     0
# 357698    150725804  07/08/2015   78  97.9239       M   33  Female     2
# 357699    150702215  06/27/2015   21  15.7762       V   51  Female     0
# 357700    151124313  11/01/2015   79  85.7374       S    3    Male     1
# 357701    151124428  11/02/2015   68  97.9239       M   21  Female     1
# 357702    151115064  11/04/2015   73  85.7374       S   12  Female     0
# 357703    151100368  10/28/2015   73  83.2157       S   85  Female     0
# 357704    150639249  06/08/2015   33  15.7762       V    4    Male     1
# 357705    150639257  06/08/2015   33  15.7762       V    5  Female     1
# 357706    150630000  05/20/2015   16  97.9239       M    5  Female     2
# 357707    150528367  01/13/2015   14  49.2646       M   85  Female     0
# 357708    150528459  05/12/2015   21  15.0591       V   12  Female     0
# 357709    150619154  05/13/2015   26  15.0591       V   27    Male     3
# 357710    150554802  05/15/2015   31   5.6748       C   15    Male     2
# 357711    150643117  05/31/2015   90   5.6748       C  201    Male     1
# 357712    150607827  05/27/2015   32   5.6748       C  218    Male     1
# 357713    150600190  05/28/2015   73  80.8381       S    5    Male     0
# 357714    150648619  06/17/2015   95  15.7762       V   52  Female     1
# 357715    150640832  06/08/2015   67  15.7762       V    8  Female     0
# 357716    150633445  05/31/2015   50  74.8813       L  220  Female     0
# 357717    150633526  04/04/2015   14  49.2646       M   51  Female     0
# 357718    150628863  06/08/2015   95  15.7762       V   30  Female     1
# 357719    150607637  05/22/2015   32   5.6748       C  215  Female     2
# 357720    150747209  07/24/2015   73  83.2157       S   14  Female     0
# 357721    150747217  07/24/2015   73  83.2157       S    2    Male     0
# 357722    150739278  05/31/2015   23  15.0591       V    7    Male     0
# 357723    150733393  07/11/2015   18   5.6748       C    3  Female     2
# 357724    150819286  07/24/2015   21  15.7762       V   38    Male     0
# 357725    150823002  08/08/2015   78  97.9239       M   38  Female     1
# 357726    150723074  06/20/2015   54  49.2646       M    5  Female     1
#
#        race_other  diag        diag_other  body_part  disposition  location  \
# 0             NaN    57               NaN         33            1         9
# 1             NaN    57               NaN         34            1         1
# 2             NaN    71    OTITIS EXTERNA         94            1         0
# 3             NaN    71              PAIN         35            1         0
# 4        HISPANIC    62               NaN         75            1         0
# 5             NaN    71  DOG SCRATCH/BITE         76            1         1
# 6             NaN    51               NaN         33            4         9
# 7             NaN    57               NaN         30            1         0
# 8             NaN    59               NaN         76            1         1
# 9             NaN    53               NaN         79            1         5
# 10            NaN    59               NaN         82            1         1
# 11            NaN    57               NaN         36            1         9
# 12            NaN    60               NaN         88            1         0
# 13            NaN    62               NaN         75            1         1
# 14            NaN    53               NaN         93            1         1
# 15            NaN    59               NaN         82            1         0
# 16            NaN    59               NaN         83            1         1
# 17            NaN    57               NaN         92            1         1
# 18            NaN    64               NaN         79            1         1
# 19            NaN    59               NaN         76            1         1
# 20            NaN    64               NaN         79            1         0
# 21            NaN    59               NaN         35            4         1
# 22            NaN    58               NaN         75            1         0
# 23            NaN    57               NaN         34            1         0
# 24            NaN    58               NaN         76            1         1
# 25            NaN    58               NaN         75            1         0
# 26            NaN    64               NaN         93            1         0
# 27            NaN    71            OTITIS         94            1         0
# 28            NaN    62               NaN         75            4         1
# 29            NaN    64               NaN         31            1         0
# ...           ...   ...               ...        ...          ...       ...
# 357697        NaN    60               NaN         88            1         9
# 357698        NaN    71              PAIN         94            1         0
# 357699        NaN    53               NaN         83            1         1
# 357700        NaN    59               NaN         88            1         1
# 357701        NaN    64               NaN         79            1         1
# 357702        NaN    64               NaN         37            1         9
# 357703        NaN    57               NaN         80            4         1
# 357704        NaN    59               NaN         75            1         1
# 357705        NaN    57               NaN         76            2         0
# 357706        NaN    59               NaN         94            1         1
# 357707        NaN    57               NaN         79            5         1
# 357708        NaN    59               NaN         92            1         1
# 357709   HISPANIC    59               NaN         33            1         1
# 357710        NaN    64               NaN         37            1         9
# 357711        NaN    62               NaN         75            1         1
# 357712        NaN    71              LIMP         36            1         1
# 357713        NaN    56               NaN         94            1         0
# 357714        NaN    64               NaN         30            1         1
# 357715        NaN    64               NaN         32            1         0
# 357716        NaN    68               NaN         85            1         0
# 357717        NaN    56               NaN         92            1         1
# 357718        NaN    64               NaN         79            1         1
# 357719        NaN    59               NaN         94            1         0
# 357720        NaN    62               NaN         75            1         5
# 357721        NaN    62               NaN         75            1         1
# 357722        NaN    59               NaN         76            1         1
# 357723        NaN    68               NaN         85            1         0
# 357724        NaN    71              PAIN         79            1         0
# 357725        NaN    59               NaN         82            1         1
# 357726        NaN    57               NaN         34            1         9
#
#         fmv  prod1   prod2                                              narr1  \
# 0         0   1267     NaN  5 YR OLD MALE PLAYING SOCCER BLOCKING BALL AND...
# 1         0   1439  4057.0  L WRIST FX(?)/36YOWM 2 WKS AGO@G-FRIENDS HM,MO...
# 2         0   3274     NaN  20 YO F C/O EAR PAIN 1 DAY SAS WAS SWIMMING YE...
# 3         0    611     NaN  61YOM W/KNEE PAIN S/P FALLING IN SHOWER 2 DAYS...
# 4         0   1893  1807.0  88YOF PAIN TO HEAD WHEN FALL TO FLOOR WHEN WAL...
# 5         0   1715     NaN  16 MOF AT HOME PULLED FAMILY DOG-HUSKIES COLLA...
# 6         3   1138     NaN  25 YOM WAS CAMPING WHEN FRIEND THREW A PRESSUR...
# 7         0   5040     NaN  53 YOM BIKE WRECK SUNDAY PAIN CHEST SHOULDER &...
# 8         0   1807     NaN          98 Y/O M FELL IN FLOOR AND LACERATED FACE
# 9         0   4057  1807.0  48 YO F, C/O RT FLANK PAIN 6 DAYS S/P FALL WAS...
# 10        0   1894     NaN  20 YOM DX HAND LACERATION - S/P PT PUNCHED A W...
# 11        0   1267     NaN  L DISTAL FIB FX/20YOWF WHILE PLAYING SOCCER AT...
# 12        0   3274  1284.0  DX LOSS TEETH D/T TRAUME: 11YOM LOOSE LOWER R ...
# 13        0   1807     NaN  CHI,LEFT WRIST SPRAIN.26YOF SLIPPED AND FELL O...
# 14        0   4057     NaN     33 YOM SMASHED FOOT INTO COFFEE TABLE LAST PM.
# 15        0    894     NaN                     36 YOM CUT HAND WITH A HACKSAW
# 16        0   1817     NaN  65 YO WF CUT FOOT WHEN BARE FOOTED ON PORCH AT...
# 17        0    380     NaN  2YOM INJURED FINGER BY PUTTING IT IN A HOUSE F...
# 18        0   4014     NaN  LUMBAR STRIAN. 69 YOF STRAINED HER LOWER BACK ...
# 19        0    474     NaN          4 M/.O F   BROTHER  DROPPED  CUP  ON FACE
# 20        0    676     NaN  LUMBAR STR.  47YOF STRAINED LOWER BACK RIPPING...
# 21        0   5036     NaN  16 YOM TRIED TO DO A WHEELIE ON HIS DIRT BIKE ...
# 22        0   1239     NaN  31 YOM WAS THROWN FROM A HORSE INTO A TREE AND...
# 23        0   1329     NaN   7YOM SUST WRIST FX WHEN HE FELL OFF HIS SCOOTER*
# 24        0    611     NaN  27YOF H'TOMA F'HEAD - SYNCOPE, FELL GETTING OU...
# 25        0    679  1807.0  9 MO F AT 11:30AM TODAY FELL APPROX 2 FT FT BA...
# 26        0   1884     NaN  27 YO F C/O LT 5TH TOE PAIN REPORTS STUBBING T...
# 27        0   3274     NaN  39YOM DOING ALOT OF SWIMMING AND NOW EARS HURT...
# 28        0   4076     NaN  7 MONTH M WITH CHI HIT HEAD, FELL FROM BED - A...
# 29        0   1211     NaN  14YOM PAIN TO BACK AND HEAD WHEN PLAYING FOOTB...
# ...     ...    ...     ...                                                ...
# 357697    0   5017     NaN  DX DENTAL INJ 4YOM PATIENT WAS STRUCK IN HIS M...
# 357698    0   1616     NaN  33 YOF INJURED EAR WEARING EARRINGS 2 DAYS AGO...
# 357699    0   1426     NaN  51YF ACC STRUCK FOOT C AN AXE HANDLE WHILE HEL...
# 357700    0   4076     NaN     3YOM JUMPED OFF OF BED HIT MOUTH HAS A LIP LAC
# 357701    0   4014     NaN  21 YOF C/O LOW BACK PAIN AFTER HELPING MOVE HE...
# 357702    0   1233     NaN  12YOF JUMPING ON A TRAMPOLINE AT *** AND STRAI...
# 357703    0   1807     NaN  85YOF FELL TO HER BATHROOM FLOOR AND FRACTURED...
# 357704    0   3262     NaN         4 YOM FELL OFF POOL LADDER  DX:  SCALP LAC
# 357705    0   3286     NaN  5 YOF 4 WHEELERS ACCIDENT, EJECTED D X:  MULTI...
# 357706    0   1871     NaN  5 YOF MOTHER STATES CHILD RAN INTO A FENCE AT ...
# 357707    0    676  1884.0                85YOF FX HIP- TRIPPED RUG, HIT WALL
# 357708    0    464     NaN  12YF ACC CUT FINGER ON A KNIFE CUTTING ICECREA...
# 357709    0    836     NaN          27 YOM LAC TO ARM WHEN USING A BOX CUTTER
# 357710    0   1205     NaN    15 YO MALE PLAYING BASKETBALL.  DX ANKLE SPRAIN
# 357711    0   4076  1807.0  1MOM-PT & 5YOLD SIBLING WERE LAYING ON THE BED...
# 357712    0   1807     NaN  18 MOM PLAYING WITH BROTHER THIS A.M. AND FELL...
# 357713    0   1936     NaN                  5YOM PUT A BB IN RIGHT EAR FB EAR
# 357714    0   1842     NaN  RT SHOULDER STR.  52YOF FELL GOING DOWN A FLIG...
# 357715    0   3216     NaN  DX ELBOW STRAIN R: 8YOF FELL YTDY W ROLLER SKA...
# 357716    0   1913     NaN  20 MOF TOXIC INGESTION, MOM REPORTS WITNESSING...
# 357717    0   1616     NaN                  51YOF F'BDY- RING STUCK ON FINGER
# 357718    0   1522     NaN  LUMBAR STRAIN. 30 YOF STRAINED HER LOWER BACK ...
# 357719    0   1616     NaN  15 MOF R EARRING WAS PULLED OUT OF EAR RESULTI...
# 357720    0   1807     NaN  14YOF AT THE HOSPITAL WAS WITNESSING HER SISTE...
# 357721    0   1301     NaN  2YOM FELL OFF HIS TRICYCLE TO THE DRIVEWAY ONT...
# 357722    0   1864     NaN  7 YO MALE HIT CORNER OF COUNTER WHILE PLAYING....
# 357723    0   1931     NaN     3 YOF INGESTED 60 VITAMIN ***.  DX: INGESTION.
# 357724    0   3250     NaN  38YM C/O WORSENING LBP THAT STARTED WHILE LIFT...
# 357725    0    464     NaN  38 YOF INJURED HAND, CUT WITH BREAD KNIFE AT H...
# 357726    0   3273     NaN  5YOF ON A PLAYGROUND & FELL OFF PLAY STRUCTURE...
#
#                                                     narr2
# 0                                                    X IT
# 1       AN OBJECT&TWISTED WRIST TRYING TO CONTOL MOWER...
# 2       T TRIED TO USE ***S TO REMOVE WAX MADE IT WORS...
# 3                                                     NaN
# 4                DOOR AND FELL.DENIES LOC. DX HEAD INJURY
# 5       ND SCRAPING TEETH ON PTS FACE, NOT A TRUE BITE...
# 6       WHICH FLASHED. FD NS. DX:  BURNS L UPPER & LOW...
# 7                                                     NaN
# 8                                                     NaN
# 9       ABLE WHICH HIT THE FLOOR STRIKING RT FLANK DX ...
# 10                                                    NaN
# 11                       LE CAUSING INJURY TO DISTAL FIB.
# 12                      M OF POOL KNOCKING HIS TOOTH LOSE
# 13                                                    NaN
# 14                   DX:  L TOE CONT, SUBUNGUAL HEMATOMA.
# 15                                   DX:  HAND LACERATION
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                              LAC  FACE
# 20                                                    NaN
# 21      IKE. DX LACERATION. DEEP DIRTY WOUND LEFT KNEE...
# 22                                     DX  SCALP HEMATOMA
# 23                                                    NaN
# 24                                                    NaN
# 25                RDWOOD FLOOR CRIED DX PARIETAL HEMATOMA
# 26                                        L DX TOE SPRAIN
# 27                                                    NaN
# 28                                                    NaN
# 29                    OTHER PLAYER. +DAZED. / BACK STRAIN
# ...                                                   ...
# 357697                                                NaN
# 357698                                                NaN
# 357699                                            >>CONTS
# 357700                                                NaN
# 357701                      ME. DX LOW BACK SPRAIN STRAIN
# 357702                                                NaN
# 357703                                                NaN
# 357704                                                NaN
# 357705                                                NaN
# 357706                         DX LACERATION TO RIGHT EAR
# 357707                                                NaN
# 357708                                              >>LAC
# 357709                                                NaN
# 357710                                                NaN
# 357711  FELL OFF BED ONTO THE FLOOR CRYING HIT HEAD. D...
# 357712                         BEEN LIMPING SINCE DX LIMP
# 357713                                                NaN
# 357714                                          SHOULDER.
# 357715                             O R ELBOW AND WRIST PN
# 357716  IR GEL THEN PUT THE GEL IN HER MOUTH, BEGAN VO...
# 357717                                                NaN
# 357718                       STRAP A CHILD IN A STROLLER.
# 357719                                     TO BACK OF EAR
# 357720  PASSED OUT TO THE FLOOR ONTO HEAD CLOSED HEAD ...
# 357721                                                NaN
# 357722                                                NaN
# 357723                                                NaN
# 357724                                              >>LBP
# 357725                                         LACERATION
# 357726         +PAIN TO RT WRIST & FOREARM.  DX; WRIST FX
#
# [357727 rows x 19 columns]

# %% [markdown]
# ## Graph the count of men and women, but don’t included the “Not Recorded” records
#
# Yes, again! The code you use should be different this time.

# %%
df.sex.value_counts()
# Out:
# Male      195071
# Female    162654
# Name: sex, dtype: int64

# %%
df.sex.value_counts().plot(kind = 'barh')

# %%
df.sex.value_counts(dropna = False)
# Out:
# Male      195071
# Female    162654
# NaN            2
# Name: sex, dtype: int64

# %% [markdown]
# # Wall punching

# %% [markdown]
# ## Find every instance where the narrative includes punching a wall
#
# Include phrases like "punched a wall" or "punch wall" or "punched ten thousand walls." Do not type them each individually. How do you do that?????

# %%
#wall_punch = df[(df['narr1'].str.contains('PUNCH WALL')) | (df['narr2'].str.contains('PUNCH WALL'))]
#contains('F[AE]LL,*BI[CK]')
wall_punch = df[df.narr1.str.contains('PUNCH.*WALL') | df.narr2.str.contains('PUNCH.*WALL')]
wall_punch
# Out:
#         CPSC Case #   trmt_date  psu   weight stratum  age     sex  race  \
# 246       150532226  05/07/2015   63  97.9239       M   38    Male     0
# 582       150954076  09/16/2015   22  15.7762       V   13    Male     1
# 604       150541260  04/09/2015   53  15.0591       V   22    Male     1
# 704       151017458  10/05/2015   61  16.5650       V   15  Female     1
# 741       150433154  04/02/2015   91  15.0591       V   33    Male     1
# 782       150805902  07/22/2015    3  74.8813       L   28    Male     0
# 1098      150455805  03/27/2015   93  15.0591       V   25  Female     1
# 1571      150519707  04/21/2015   77  15.0591       V   14    Male     0
# 1616      151112964  09/21/2015   26  15.7762       V   16    Male     2
# 1660      150446653  04/14/2015   33  15.0591       V   52    Male     1
# 1707      160113449  12/22/2015   68  97.9239       M   20  Female     1
# 2064      150347487  03/15/2015   44  74.8813       L   26    Male     1
# 2669      150663851  06/13/2015  101  97.9239       M   22  Female     0
# 2714      150255182  02/25/2015   58  15.7762       V   13    Male     0
# 2953      150834668  08/12/2015   78  97.9239       M   24    Male     2
# 3126      151114759  10/05/2015   90   5.6748       C   17    Male     1
# 3150      151036494  10/10/2015   91  16.5650       V   18  Female     3
# 3260      150452382  04/19/2015   51  74.8813       L   21    Male     2
# 3714      150809087  06/09/2015   23  15.7762       V   20  Female     0
# 3794      150717882  07/04/2015    7  83.2157       S   20    Male     0
# 3820      151036567  10/09/2015   51  74.8813       L   39    Male     1
# 4019      151006820  10/02/2015   21  16.5650       V   15  Female     0
# 4305      150458204  04/23/2015    8   5.6748       C   16    Male     1
# 4646      150727133  07/08/2015   51  74.8813       L   16    Male     1
# 4734      150828645  07/21/2015   54  49.2646       M   15    Male     1
# 4825      150739139  07/11/2015   37   5.6748       C   16  Female     0
# 4856      150955366  09/16/2015   95  15.7762       V   31    Male     1
# 4910      151049864  10/19/2015   58  16.5650       V   31    Male     0
# 4927      150666370  06/28/2015   95  15.7762       V   19    Male     1
# 5057      150514524  05/05/2015   21  15.0591       V   15    Male     0
# ...             ...         ...  ...      ...     ...  ...     ...   ...
# 352195    150544423  05/02/2015   77  15.0591       V   17  Female     0
# 352414    151206693  10/27/2015   43  83.2157       S   38    Male     1
# 352646    150130872  01/10/2015   77  15.0591       V   13  Female     1
# 352716    150822410  07/26/2015   21  15.7762       V   20    Male     0
# 352767    150615627  05/24/2015    5  37.6645       L   18    Male     3
# 353101    150146728  01/23/2015   21  15.0591       V   14    Male     0
# 353627    150425410  04/06/2015   95  15.0591       V   24  Female     1
# 353694    150623912  03/29/2015   14  49.2646       M   22    Male     0
# 353864    151225136  11/13/2015   14  49.2646       M   28    Male     0
# 353867    151240077  10/17/2015   24  97.9239       M   16    Male     4
# 354002    150639850  05/29/2015   46  80.8381       S   22    Male     1
# 354321    150300001  02/07/2015   73  80.8381       S   16    Male     0
# 354324    150550556  05/06/2015   33  15.0591       V   15    Male     1
# 354377    150342757  03/11/2015   44  74.8813       L   52    Male     1
# 354598    151227583  12/06/2015   41  16.5650       V   60  Female     2
# 354673    150838635  07/22/2015   50  74.8813       L   24    Male     0
# 355252    151208335  11/30/2015   95  16.5650       V   20    Male     1
# 355335    151157308  11/23/2015    3  74.8813       L   44    Male     0
# 355336    151241535  12/17/2015   95  16.5650       V   49  Female     1
# 355570    151258595  12/11/2015   57  16.5650       V   18    Male     2
# 355659    150440780  04/16/2015    2  15.0591       V   25    Male     0
# 355761    150304580  02/25/2015    8   5.6748       C   18    Male     2
# 356073    150647058  05/21/2015    3  74.8813       L   29  Female     0
# 356137    150119524  01/05/2015   64  15.0591       V   24    Male     1
# 356390    150700501  06/15/2015   41  15.7762       V   21    Male     0
# 356484    151229439  12/07/2015    5  37.6645       L   34    Male     1
# 356975    150425370  04/05/2015   95  15.0591       V   29    Male     1
# 356995    150620540  06/01/2015   42  74.8813       L   21    Male     1
# 357305    150971840  09/27/2015   95  15.7762       V   16  Female     1
# 357412    151058001  09/24/2015   92  83.2157       S   28    Male     1
#
#        race_other  diag     diag_other  body_part  disposition  location  fmv  \
# 246           NaN    57            NaN         82            1         0    0
# 582           NaN    57            NaN         82            1         1    0
# 604           NaN    71    HAND INJURY         82            1         1    0
# 704           NaN    53            NaN         82            1         1    0
# 741           NaN    57            NaN         82            1         0    0
# 782           NaN    71       HAND INJ         82            1         0    0
# 1098          NaN    53            NaN         82            1         0    0
# 1571          NaN    57            NaN         82            1         0    0
# 1616          NaN    53            NaN         82            1         5    0
# 1660          NaN    57            NaN         82            1         1    0
# 1707          NaN    71           PAIN         92            1         1    0
# 2064          NaN    71         INJURY         82            1         1    0
# 2669          NaN    64            NaN         82            1         1    0
# 2714          NaN    57            NaN         82            1         1    0
# 2953          NaN    55            NaN         82            1         1    0
# 3126          NaN    53            NaN         82            1         5    0
# 3150     HISPANIC    53            NaN         82            1         0    0
# 3260          NaN    53            NaN         82            1         0    0
# 3714          NaN    57            NaN         82            1         0    0
# 3794          NaN    57            NaN         82            1         0    0
# 3820          NaN    53            NaN         82            6         0    0
# 4019          NaN    71           PAIN         82            1         8    0
# 4305          NaN    57            NaN         82            1         0    0
# 4646          NaN    71  PAIN SWELLING         82            2         5    0
# 4734          NaN    71             NS         87            1         1    0
# 4825          NaN    57            NaN         82            1         0    0
# 4856          NaN    57            NaN         82            1         1    0
# 4910          NaN    53            NaN         82            1         0    0
# 4927          NaN    53            NaN         82            1         1    0
# 5057          NaN    57            NaN         82            1         5    0
# ...           ...   ...            ...        ...          ...       ...  ...
# 352195        NaN    57            NaN         82            1         5    0
# 352414        NaN    57            NaN         82            1         1    0
# 352646        NaN    53            NaN         82            1         8    0
# 352716        NaN    71           PAIN         82            1         0    0
# 352767   HISPANIC    57            NaN         82            1         0    0
# 353101        NaN    53            NaN         82            1         0    0
# 353627        NaN    64            NaN         82            1         1    0
# 353694        NaN    57            NaN         82            1         1    0
# 353864        NaN    53            NaN         82            1         1    0
# 353867        NaN    57            NaN         82            1         0    0
# 354002        NaN    71      HAND PAIN         82            1         1    0
# 354321        NaN    64            NaN         34            1         0    0
# 354324        NaN    53            NaN         82            1         1    0
# 354377        NaN    57            NaN         82            1         0    0
# 354598        NaN    71           PAIN         82            1         0    0
# 354673        NaN    53            NaN         82            1         0    0
# 355252        NaN    57            NaN         82            1         0    0
# 355335        NaN    57            NaN         82            1         0    0
# 355336        NaN    53            NaN         82            1         1    0
# 355570        NaN    71      HAND PAIN         82            1         0    0
# 355659        NaN    53            NaN         82            1         0    0
# 355761        NaN    57            NaN         82            1         1    0
# 356073        NaN    53            NaN         82            1         0    0
# 356137        NaN    53            NaN         82            1         1    0
# 356390        NaN    71           PAIN         82            1         0    0
# 356484        NaN    57            NaN         82            1         0    0
# 356975        NaN    57            NaN         82            1         1    0
# 356995        NaN    53            NaN         82            1         0    0
# 357305        NaN    53            NaN         82            1         1    0
# 357412        NaN    71           PAIN         82            1         1    0
#
#         prod1   prod2                                              narr1  \
# 246      1884     NaN                38YOM PUNCHED A WALL FRACTURED HAND
# 582      1884     NaN  PT PUNCHED A WALL. FRACTURE METACARPAL, RIGHT,...
# 604      1884     NaN  22YOM-HAND INJURY-PUNCHED A CEMENT WALL IN ANG...
# 704      1884     NaN  15 YOF C/O RIGHT HAND PAIN SINCE PUNCHING A WA...
# 741      1884     NaN  33YOM PUNCHED A WALL X1 WEEK AGO W/ SHARP PAIN...
# 782      1884     NaN               28YOM PUNCHED A WALL AND INJ RT HAND
# 1098     1884     NaN                             25 YOF PUNCHED A WALL.
# 1571     1884     NaN      14YOM SUST FX TO HAND WHEN HE PUNCHED A WALL*
# 1616     1884     NaN     16 YOM CONTUSION TO HAND AFTER PUNCHING A WALL
# 1660     1884     NaN         52 YOM PUNCHED WALL L HAND  DX:  FX 5TH MC
# 1707     1884     NaN  20 YOF PUNCHED A WALL SEVERAL WEEKS AGO. NOW H...
# 2064     1884     NaN  26 YOM PUNCHED WALL WITH BOTH HANDS DX CLINCHE...
# 2669     1884     NaN  22YOF PUNCHED A WALL WITH RIGHT HAND, RIGHT HA...
# 2714     1884     NaN             13 YOM PUNCHED A WALL AND INJURED HAND
# 2953     1884     NaN  24 YOM INJURED HAND, PUNCHED A WALL AT HOME. D...
# 3126     1884     NaN  17 YOM GOT ANGRY & PUNCHED A WALL WITH HIS RT....
# 3150     1884     NaN  18YOF C/O R HADN PAIN AFTER PUNCHING A BRICK W...
# 3260     1884     NaN  21 YO M, C/O NOTICING DEFORMITY TO RT HAND S/P...
# 3714     1884     NaN  20 YO FEMALE HURT PUNCHING A WALL AT UNSPECIFI...
# 3794     1884     NaN            20 Y O M FX HAND WHEN HE PUNCHED A WALL
# 3820     1884     NaN  39 YO M C/O RIGHT HAND PAIN REPORTS PUNCHING A...
# 4019     1884     NaN  15YF P ARGUMENT C THE TEATCH PUNCHED A WALL IN...
# 4305     1884     NaN               16YOM PUNCHED A BRICK WALL; HAND FX.
# 4646     1884     NaN  16 YO M, C/O HAND PAIN SWELLING S/P PUNCHING A...
# 4734     1884     NaN  15YOM HAD FIGHT W/FATHER; SHOVED PARENTS, PUNC...
# 4825     1884     NaN  16 YO F WAS GOING TO HIT BROTHER, MISSED HIM A...
# 4856     1884     NaN              RIGHT HAND FX. 31 YOM PUNCHED A WALL.
# 4910     1884     NaN         31 YOM PUNCHED A WALL AND IS C/O HAND PAIN
# 4927     1884     NaN            RT HAND CONTUSION.19YOM PUNCHED A WALL.
# 5057     1884     NaN  15YM FROM JUBENILE DETENTION C HAND PAIN P PUN...
# ...       ...     ...                                                ...
# 352195   1884     NaN     17YOF SUST FX TO HAND WHEN SHE PUNCHED A WALL*
# 352414   1884     NaN  L HAND FX/38YOWM AT HOME TODAY PUNCHED A WALL....
# 352646   1884     NaN  13 YOF INJURED RT HAND YESTERDAY WHEN SHE PUNC...
# 352716   1884     NaN  20YM C/O LT HAND PAIN P PUNCHING A WALL C CLOS...
# 352767   1884     NaN                     18 YOM PUNCHED WALL YESTERDAY.
# 353101   1884     NaN  14YM RHD, C/O RT HANDPAIN P PUNCHING A TREE VS...
# 353627   1884     NaN           HAND SPR.  24YOF PUNCHED WALL WITH HAND.
# 353694   1884     NaN                        22YOM FX HAND- PUNCHED WALL
# 353864   1884     NaN                       28YOM CONT HAND - PUNCH WALL
# 353867   1884     NaN  J/ 16 YOM. RT HAND PAIN AFTER PUNCHING THE WAL...
# 354002   1884     NaN       22YOM PUNCHED WALL WITH HAND. DX: HAND PAIN.
# 354321   1884     NaN  16YOM WAS ANGRY AND PUNCHED A WALL AND STRAINE...
# 354324   1884     NaN  15 YOM R HAND PAIN, PUNCHED WALL  DX:  HAND CO...
# 354377   1884     NaN        52 YOM PUNCHED WALL DXD METACARPAL FRACTURE
# 354598   1884     NaN  60YOF W/HAND PAIN 2/2 PUNCHING A WALL 3 MONTHS...
# 354673   1884     NaN  24 YOM HAND CONTUSION, PUNCHED A WALL WITH CLO...
# 355252   1884     NaN       HAND FX.  20YOM PUNCHED WALL AND BROKE HAND.
# 355335   1884     NaN  44YOM PUNCHED A WALL 1 MONTH PTA.  FRACTURE OF...
# 355336   1884     NaN            RT HAND CONTUSION.49YOF PUNCHED A WALL.
# 355570   1884     NaN  18 YOM DX HAND PAIN/INJURY - S/P PT PUNCHED A ...
# 355659   1884     NaN  25YOM ANGRY AND PUNCHED A WALL SUSTAINED AN AB...
# 355761   1884  1893.0  18YOM PUNCHED A WALL OR DOOR WHEN ANGRY LAST N...
# 356073   1884     NaN                               29YOF PUNCHED A WALL
# 356137   1807  1884.0  24YOM PT COMPLAINING OF PUNCHING A WALL AFTER ...
# 356390   1884     NaN  21YOM W/HAND PAIN 2/2 PUNCHING A CONCRETE WALL...
# 356484   1884     NaN                  34 YOM PUNCHED A WALL 7 DAYS AGO.
# 356975   1884     NaN       HAND FX.  29YOM PUNCHED WALL AND BROKE HAND.
# 356995   1884     NaN  21YOM PAIN TO R HAND WHEN PUNCHED A WALL. DX H...
# 357305   1884     NaN       RIGHT HAND CONTUSION. 16 YOF PUNCHED A WALL.
# 357412   1207  1884.0  28YOM WAS HITTING PUNCHING BAG AND MISSED HITT...
#
#                                                     narr2
# 246                                                   NaN
# 582                                                   NaN
# 604                                                   NaN
# 704                                 DX: CONTUSION OF HAND
# 741     DX: ACUTE CLOSED FX OF FIFTH METACARPAL, BOXER...
# 782                                                   NaN
# 1098                                    DX:  R HAND CONT.
# 1571                                                  NaN
# 1616                                                  NaN
# 1660                                                  NaN
# 1707                PAINFUL SOMETIMES. DX LEFT THUMB PAIN
# 2064                                                  NaN
# 2669                                                  NaN
# 2714                                        DX   FRACTURE
# 2953                                                 HAND
# 3126                      DX; RT 4TH METACARPAL CONTUSION
# 3150                                MPER DX: R HAND CONTU
# 3260                                       O DX HAND CONT
# 3714                                                    B
# 3794                                                  NaN
# 3820                                            HAND CONT
# 4019                                          >>HAND PAIN
# 4305                                                  NaN
# 4646    LITY BECAME AGGRESSIVE AND AGITATED DX MOOD D/...
# 4734    ENED TO KILL PARENTS/SELF   DX: ADHD, OPPOSITI...
# 4825                                  NT DX: FX TO R HAND
# 4856                                                  NaN
# 4910                                        DX  CONTUSION
# 4927                                                  NaN
# 5057                                                 >>FX
# ...                                                   ...
# 352195                                                NaN
# 352414                                                NaN
# 352646                      AT SCHOOL. DX HAND CONTUSION%
# 352716                                             >>PAIN
# 352767                        DX:  R THIRD METACARPAL FX.
# 353101                                            >>CONTS
# 353627                                                NaN
# 353694                                                NaN
# 353864                                                NaN
# 353867                              HAND. DX: FX OF HAND.
# 354002                                                NaN
# 354321                                                NaN
# 354324                                                NaN
# 354377                                                NaN
# 354598                         VE IT LOOKED AT UNTIL NOW.
# 354673                                                NaN
# 355252                                                NaN
# 355335                                         IGHT HAND*
# 355336                                                NaN
# 355570                                                NaN
# 355659                                                NaN
# 355761                                                NaN
# 356073                                 DX: HAND CONTUSION
# 356137             HOME HAND CONTUISON DX HAND CONTUSION#
# 356390                                                NaN
# 356484                        DX:  FX R FIFTH METACARPAL.
# 356975                                                NaN
# 356995                                                NaN
# 357305                                                NaN
# 357412                                                NaN
#
# [1823 rows x 19 columns]

# %% [markdown]
# ## Graph the gender distribution of wall-punching.

# %%
wall_punch['sex'].value_counts().plot(kind = 'barh')

# %% [markdown]
# ## Find the average age of a wall-puncher.
#
# Graph the distribution of the ages, too.

# %%
wall_punch['age'].mean()
# Out:
# 24.406472846955566

# %% [markdown]
# # Which months are the most popular for wall punching?
#
# The month is hidden inside of the `trmt_date` column - you'll need to extract it. To check, January should have 27109 cases.

# %%
wall_punch['trmt_date'].str.extract('(\d\d)(/\d\d/\d\d\d\d)')[0].value_counts()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.
# 09    179
# 06    171
# 05    170
# 10    169
# 03    158
# 04    158
# 11    149
# 12    144
# 01    138
# 07    137
# 08    134
# 02    116
# Name: 0, dtype: int64

# %% [markdown]
# ## Graph the amount of wall punching in each month
#
# Having numbers on the x axis (1-12) is fine.

# %%
wall_punch['trmt_date'].str.extract('(\d\d)/\d\d/\d\d\d\d').value_counts().sort_index().plot(kind = 'barh')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Sort the graph so that the months are in order from Jan-Dec (or 01-12)

# %%
wall_punch['trmt_date'].str.extract('(\d\d)/\d\d/\d\d\d\d').value_counts().sort_index(ascending=False).plot(kind = 'barh')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## What month is most common for air conditioner-related injuries?
#
# Use the product code, which you can find in `2017ComparabilityTable.pdf` or `categories-cleaned.txt`.

# %%
df['prod1'] = df.prod1.astype(str).str.pad(4, fillchar = '0')
df['prod2'] = df.prod1.astype(str).str.pad(4, fillchar = '0')
#pad 4: we want to have a 4 digit number
## .str/ astype(str): one is a method, one is to convert the data type
df[df['prod1'] == '0381']['trmt_date'].str.extract('(\d\d)/\d\d/\d\d\d\d').value_counts()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:5: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """
# 07    45
# 06    43
# 08    42
# 09    36
# 10    32
# 05    32
# 12    17
# 04    17
# 11    15
# 03    14
# 02     9
# 01     8
# Name: trmt_date, dtype: int64

# %% [markdown]
# ## Find what else people punched using the prod1 and prod2 columns.
#
# Look at the top 10 for each separately.

# %%
punch_df = df[df.narr1.str.contains('PUNCH.*')]
punch_df['prod1'].value_counts().head(10)
# Out:
# 1884    1796
# 1894     566
# 1893     244
# 1207     159
# 4004     122
# 0276      74
# 4057      53
# 1892      48
# 1726      42
# 1807      41
# Name: prod1, dtype: int64

# %%
punch_df['prod2'].value_counts().head(10)
# Out:
# 1884    1796
# 1894     566
# 1893     244
# 1207     159
# 4004     122
# 0276      74
# 4057      53
# 1892      48
# 1726      42
# 1807      41
# Name: prod2, dtype: int64

# %% [markdown]
# ## Uh, they're the same!

# %% [markdown]
# The order of `prod1` and `prod2` don't actually matter!
#
# > When only one product is associated with an injury, place the product code for that product in the space allocated for "First Product Code" and fill in the "Second Product Code" spaces with 4 zeros (0000).
# When two products are associated with an injury, either product may be coded as the first product and the other as the second product.
# >
# > Example: An 11-year old boy riding a bicycle ran into a swing. Code: Product 1 = 5040 (bicycle) and Product 2 = 3246 (swings) or
# >
# > Code: Product 1 = 3246 (swings) and Product 2 = 5040 (bicycle)
#
# ## Okay, okay, there’s no difference between prod1 and prod2, so you should add their frequencies together for an overall count!
#
# It's *almost* as easy as adding together the `value_counts()`.
#
# Take a look at the air conditioner question and the `.value_counts()` you just did, though, to see why combining them might not be that simple. **What is different about `prod1` and `prod2`?** You probably have to go all the way back up to where you read the file in to make them match.

# %%
count = df['prod1'].value_counts() + df['prod2'].value_counts()
count
# Out:
# 1842    57218
# 1807    56510
# 4076    33414
# 1205    28190
# 5040    25474
# 1211    23228
# 4074    16478
# 1884    15510
# 1893    15378
# 4057    14654
# 0464    14562
# 0611    14368
# 1267    14280
# 3299    14114
# 0679    10162
# 1615     7346
# 4078     7330
# 1233     6394
# 4056     6232
# 5041     6126
# 1616     5898
# 1817     5866
# 1333     5716
# 1141     5662
# 1244     5384
# 0604     5270
# 1871     5216
# 3265     5098
# 1894     5038
# 0649     4950
#         ...
# 0669        4
# 0307        4
# 1854        4
# 0116        2
# 0240        2
# 0932        2
# 0958        2
# 0125        2
# 0401        2
# 1739        2
# 0462        2
# 1515        2
# 0236        2
# 0139        2
# 0558        2
# 0533        2
# 1531        2
# 0556        2
# 1517        2
# 0119        2
# 5013        2
# 1539        2
# 0221        2
# 1441        2
# 0807        2
# 0213        2
# 0223        2
# 0270        2
# 0212        2
# 1350        2
# Length: 757, dtype: int64

# %% [markdown]
# ## Turn that into a dataframe
#
# Use `.reset_index()` on the result to turn it into a dataframe. Rename your columns to be `product_code` and `injury_count`.

# %%
df0 = pd.DataFrame(count).reset_index()
df0.columns = ['product_code', 'injury_count']
df0
# Out:
#     product_code  injury_count
# 0           1842         57218
# 1           1807         56510
# 2           4076         33414
# 3           1205         28190
# 4           5040         25474
# 5           1211         23228
# 6           4074         16478
# 7           1884         15510
# 8           1893         15378
# 9           4057         14654
# 10          0464         14562
# 11          0611         14368
# 12          1267         14280
# 13          3299         14114
# 14          0679         10162
# 15          1615          7346
# 16          4078          7330
# 17          1233          6394
# 18          4056          6232
# 19          5041          6126
# 20          1616          5898
# 21          1817          5866
# 22          1333          5716
# 23          1141          5662
# 24          1244          5384
# 25          0604          5270
# 26          1871          5216
# 27          3265          5098
# 28          1894          5038
# 29          0649          4950
# ..           ...           ...
# 727         0669             4
# 728         0307             4
# 729         1854             4
# 730         0116             2
# 731         0240             2
# 732         0932             2
# 733         0958             2
# 734         0125             2
# 735         0401             2
# 736         1739             2
# 737         0462             2
# 738         1515             2
# 739         0236             2
# 740         0139             2
# 741         0558             2
# 742         0533             2
# 743         1531             2
# 744         0556             2
# 745         1517             2
# 746         0119             2
# 747         5013             2
# 748         1539             2
# 749         0221             2
# 750         1441             2
# 751         0807             2
# 752         0213             2
# 753         0223             2
# 754         0270             2
# 755         0212             2
# 756         1350             2
#
# [757 rows x 2 columns]

# %% [markdown]
# ## Fix the product codes
#
# Uh, wait, look at those product codes. "102" shouldn't be possible, it should be `0102` - this actually doesn't have to do with coding, it has to do with *the data doesn't match the codebook*.
#
# ### Add zeroes to the left of the product code until it is 4 characters long

# %% [markdown]
# ## Get meaningful names for "product code"
#
# Join with `categories-cleaned.txt` to turn the codes into actual words. **When you read in `categories-cleaned.txt`, make sure it has 803 rows and 2 columns.**

# %%
df2 = pd.read_table('categories-cleaned.txt',sep=',',header = None)
df2.columns = ['product_code', 'product_name']
df2['product_code'] = df2['product_code'].astype(str).str.pad(4, fillchar = '0')
df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-e9aa3d9041ee> in <module>()
# ----> 1 df2 = pd.read_table('categories-cleaned.txt',sep=',',header = None)
#       2 df2.columns = ['product_code', 'product_name']
#       3 df2['product_code'] = df2['product_code'].astype(str).str.pad(4, fillchar = '0')
#       4 df2
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'categories-cleaned.txt' does not exist

# %%
result = pd.merge(df0, df2, how='right',on=['product_code'])
result

# %% [markdown]
# ### Confirm that it worked by seeing if product code '0102' gives you 'Wringer washing machines"

# %%
result[result['product_code'] == '0102']

# %% [markdown]
# ## Graph the top 10 most popular products for injuries

# %%
result.head(10).plot(kind = 'barh',x = 'product_code', y = 'injury_count')
