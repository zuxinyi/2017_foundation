# %% [markdown]
# # GROUP ONE: You'll just need to plot, you won't need to join or do much analysis

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
# %matplotlib inline

# %% [markdown]
# # Make a map of power plants in the US, color coded by type

# %%
usa = gpd.read_file('cb_2016_us_state_500k/cb_2016_us_state_500k.shp')
usa.to_crs({'init': 'epsg:5071'})
ax = usa.plot(figsize = (25,30), edgecolor= 'white', color = 'lightgrey').axis('off')

# %%
df = pd.read_csv("powerplants.csv")
points = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
powerplant = gpd.GeoDataFrame(df, geometry=points)
powerplant.crs = {'init': 'epsg:5071'}
powerplant.plot(column = 'sector_nam')

# %%
ax = usa.plot(figsize=(25,30),edgecolor= 'white', color = 'lightgrey')
powerplant.plot(ax = ax, column = 'sector_nam')

# %% [markdown]
# # Make a map of air quality stations, color coded by worst air quality ever

# %%
df_air = pd.read_csv("pm25_annual_fixed.csv")
points_air = df.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
air_condition = gpd.GeoDataFrame(df_air, geometry=points_air)
air_condition.crs = {'init': 'epsg:5017'}

# %%
ax = usa.plot(figsize=(25,30),edgecolor= 'white', color = 'lightgrey')
air_condition.plot(ax = ax, column = '1st Max Value')

# %% [markdown]
# # Map all of the nuclear power plants in red, with the rest of the plants as dark grey.

# %%
df_nuclear = df[df['Nuclear_MW'] != 0]
points_nuclear = df_nuclear.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
nuclear = gpd.GeoDataFrame(df_nuclear, geometry=points_nuclear)
nuclear.crs = {'init': 'epsg:5071'}

# %%
df_nonnuclear = df[df['Nuclear_MW'] == 0]
points_nonnuclear = df_nonnuclear.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
nonnuclear = gpd.GeoDataFrame(df_nonnuclear, geometry=points_nonnuclear)
nonnuclear.crs = {'init': 'epsg:5071'}

# %%
ax = usa.plot(figsize=(25,30),edgecolor= 'white', color = 'lightblue')

nonnuclear.plot(ax = ax, color = 'darkgrey', alpha = 0.5)
nuclear.plot(ax = ax, color = 'red')

# %% [markdown]
# # GROUP TWO: For most of these you'll need a spatial join

# %% [markdown]
# ## Which power plants are in New York?

# %%
df[df['County']== 'New York']
# Out:
#       Plant_Code                         Plant_Name  \
# 1176        2493                         East River
# 1182        2503                        59th Street
# 1183        2504                        74th Street
# 3815       54808  New York University Central Plant
# 5760       57789                 Peak Power 1 Cogen
# 5768       57798                          OBP Cogen
# 6643       58815             Hilton NY Co Gen Plant
#
#                          Utility_Na  Utility_ID        sector_nam  \
# 1176  Consolidated Edison Co-NY Inc        4226  Electric Utility
# 1182  Consolidated Edison Co-NY Inc        4226  Electric Utility
# 1183  Consolidated Edison Co-NY Inc        4226  Electric Utility
# 3815            New York University       13491    Commercial CHP
# 5760              Peak Power 1, LLC       57106    Commercial CHP
# 5768                  OBP Cogen LLC       57120    Commercial CHP
# 6643  UTS Project Company HNY-1 LLC       58697           IPP CHP
#
#                City    County    Zip                   Street_Add  \
# 1176       New York  New York  10009         801 East 14th Street
# 1182       New York  New York  10019              850 12th Avenue
# 1183       New York  New York  10021            506 E 75th Street
# 3815       New York  New York  10012            251 Mercer Street
# 5760       New York  New York  10119               One Penn Plaza
# 5768       New York  New York  10036              One Bryant Park
# 6643  New York City  New York  10019  1335 Avenue of the Americas
#
#        PrimSource                  ...                   Wind_MW  Geo_MW  \
# 1176  natural gas                  ...                       0.0     NaN
# 1182  natural gas                  ...                       0.0     NaN
# 1183    petroleum                  ...                       0.0     NaN
# 3815  natural gas                  ...                       0.0     NaN
# 5760  natural gas                  ...                       0.0     NaN
# 5768  natural gas                  ...                       0.0     NaN
# 6643  natural gas                  ...                       0.0     NaN
#
#       Other_MW                                 source_des  \
# 1176       NaN                     Natural Gas = 629.3 MW
# 1182       NaN                      Natural Gas = 14.9 MW
# 1183       NaN                        Petroleum = 37.7 MW
# 3815       NaN  Natural Gas = 12.8 MW, Petroleum = 4.2 MW
# 5760       NaN                         Natural Gas = 6 MW
# 5768       NaN                       Natural Gas = 4.6 MW
# 6643       NaN                       Natural Gas = 1.8 MW
#
#                                               tech_desc  \
# 1176  Natural Gas Steam Turbine; Natural Gas Fired C...
# 1182               Natural Gas Fired Combustion Turbine
# 1183                                  Petroleum Liquids
# 3815  Natural Gas Fired Combined Cycle; Petroleum Li...
# 5760             Natural Gas Internal Combustion Engine
# 5768               Natural Gas Fired Combustion Turbine
# 6643             Natural Gas Internal Combustion Engine
#
#                              Source  Period   Latitude  Longitude  \
# 1176  EIA-860, EIA-860M and EIA-923  201607  40.728100 -73.974200
# 1182  EIA-860, EIA-860M and EIA-923  201607  40.771285 -73.991150
# 1183  EIA-860, EIA-860M and EIA-923  201607  40.768000 -73.951500
# 3815  EIA-860, EIA-860M and EIA-923  201607  40.789900 -73.923300
# 5760  EIA-860, EIA-860M and EIA-923  201607  40.751111 -73.991667
# 5768  EIA-860, EIA-860M and EIA-923  201607  40.754865 -73.983248
# 6643  EIA-860, EIA-860M and EIA-923  201607  40.762500 -73.979167
#
#                                   geometry
# 1176              POINT (-73.9742 40.7281)
# 1182           POINT (-73.99115 40.771285)
# 1183               POINT (-73.9515 40.768)
# 3815              POINT (-73.9233 40.7899)
# 5760  POINT (-73.99166700000001 40.751111)
# 5768          POINT (-73.983248 40.754865)
# 6643            POINT (-73.979167 40.7625)
#
# [7 rows x 29 columns]

# %% [markdown]
# ## Which state produces the most energy from coal?

# %%
df.columns
# Out:
# Index(['Plant_Code', 'Plant_Name', 'Utility_Na', 'Utility_ID', 'sector_nam',
#        'City', 'County', 'Zip', 'Street_Add', 'PrimSource', 'Total_MW',
#        'Coal_MW', 'NG_MW', 'Crude_MW', 'Bio_MW', 'Hydro_MW', 'HydroPS_MW',
#        'Nuclear_MW', 'Solar_MW', 'Wind_MW', 'Geo_MW', 'Other_MW', 'source_des',
#        'tech_desc', 'Source', 'Period', 'Latitude', 'Longitude', 'geometry'],
#       dtype='object')

# %% [markdown]
# ## Which state produces the most energy from coal?

# %%
df.sort_values(by = 'Coal_MW', ascending = False).head(1)['County']
# Out:
# 1973    Monroe
# Name: County, dtype: object

# %% [markdown]
# ## Map states with nuclear power plants in red, and states without in grey. Do the same thing for solar.

# %%
usa.loc[4].geometry

# %%
df.loc[1]['geometry'].within(usa.loc[4].geometry)
# Out:
# False

# %%
df_nuclear = df[df['Nuclear_MW'] != 0]
df_nuclear.head()
# Out:
#      Plant_Code                     Plant_Name                    Utility_Na  \
# 22           46                   Browns Ferry    Tennessee Valley Authority
# 106         204          Clinton Power Station                Exelon Nuclear
# 108         210  Wolf Creek Generating Station  Wolf Creek Nuclear Optg Corp
# 220         371    Columbia Generating Station              Energy Northwest
# 361         566                      Millstone     Dominion Nuclear Conn Inc
#
#      Utility_ID        sector_nam        City      County    Zip  \
# 22        18642  Electric Utility     Decatur   Limestone  35609
# 106       55951       IPP Non-CHP     Clinton      DeWitt  61727
# 108       20893  Electric Utility  Burlington      Coffey  66839
# 220       20160  Electric Utility    Richland      Benton  99352
# 361        5221       IPP Non-CHP   Waterford  New London   6385
#
#                     Street_Add PrimSource  \
# 22        Shaw Rd. PO Box 2000    nuclear
# 106                Rt. 54 West    nuclear
# 108        1550 Oxen Lane N.E.    nuclear
# 220                 PO Box 968    nuclear
# 361  Route 156 Rope Ferry Road    nuclear
#
#                     ...                   Wind_MW  Geo_MW  Other_MW  \
# 22                  ...                       0.0     NaN       NaN
# 106                 ...                       0.0     NaN       NaN
# 108                 ...                       0.0     NaN       NaN
# 220                 ...                       0.0     NaN       NaN
# 361                 ...                       0.0     NaN       NaN
#
#               source_des  tech_desc                         Source  Period  \
# 22   Nuclear = 3309.4 MW    Nuclear  EIA-860, EIA-860M and EIA-923  201607
# 106    Nuclear = 1065 MW    Nuclear  EIA-860, EIA-860M and EIA-923  201607
# 108    Nuclear = 1175 MW    Nuclear  EIA-860, EIA-860M and EIA-923  201607
# 220    Nuclear = 1158 MW    Nuclear  EIA-860, EIA-860M and EIA-923  201607
# 361  Nuclear = 2087.8 MW    Nuclear  EIA-860, EIA-860M and EIA-923  201607
#
#      Latitude  Longitude                             geometry
# 22   34.70420  -87.11890             POINT (-87.1189 34.7042)
# 106  40.17190  -88.83390             POINT (-88.8339 40.1719)
# 108  38.23926  -95.68978  POINT (-95.68978 38.23925999999999)
# 220  46.47110 -119.33390            POINT (-119.3339 46.4711)
# 361  41.31070  -72.16770             POINT (-72.1677 41.3107)
#
# [5 rows x 29 columns]

# %%
#nuclear.within(usa.loc[4].geometry)
#nyc['gallery_count'] = nyc.apply(lambda row: gallery.within(row.geometry).sum(), axis=1)
usa['nuclear_power_plants'] = usa.apply(lambda row: nuclear.within(row.geometry).sum(), axis = 1)
nuclear_state = usa[usa['nuclear_power_plants'] != 0]
nonuclear_state =  usa[usa['nuclear_power_plants'] == 0]

# %%
nuclear_state.crs = {'init': 'epsg:5071'}
nonuclear_state.crs = {'init': 'epsg:5071'}
usa = usa.to_crs({'init': 'epsg:5071'})

# %%
#ax = usa.plot(figsize=(25,30),edgecolor= 'white', color = 'lightblue')
ax = nonuclear_state.plot(figsize = (25,30),color = 'darkgrey', alpha = 0.5)
nuclear_state.plot(ax = ax, color = 'red').axis('off')
# Out:
# (-197.09527795, 197.72483894999999, -18.84439205, 75.660855049999995)

# %% [markdown]
# # Make a map of total wind (or solar or coal) energy produced by each state, with little being a light color and high emissions being a brighter/darker color.

# %%
powerplant_state = gpd.sjoin(powerplant, usa, how = 'left', op = 'within')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-187adc596d31> in <module>()
# ----> 1 powerplant_state = gpd.sjoin(powerplant, usa, how = 'left', op = 'within')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/geopandas/tools/sjoin.py in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#      55     idxmatch = idxmatch[idxmatch.apply(len) > 0]
#      56
# ---> 57     r_idx = np.concatenate(idxmatch.values)
#      58     l_idx = np.concatenate([[i] * len(v) for i, v in idxmatch.iteritems()])
#      59
#
# ValueError: need at least one array to concatenate

# %% [markdown]
# #df.groupby('County')['Solar_MW'].sum()
# df.head()

# %%
powerplant.crs
# Out:
# {'init': 'epsg:5071'}

# %% [markdown]
# # Make a map of worst air quality measured in each state, with high quality being light red and low quality being dark red

# %%
powerplant.head()
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
# 3           7             Gadsden  Alabama Power Co         195
# 4           8              Gorgas  Alabama Power Co         195
#
#          sector_nam       City      County    Zip            Street_Add  \
# 0  Electric Utility  Northport  Tuscaloosa  35476    19001 Lock 17 Road
# 1  Electric Utility      Bucks      Mobile  36512      North Highway 43
# 2  Electric Utility   Wetumpka      Elmore  36092  750 Bouldin Dam Road
# 3  Electric Utility    Gadsden      Etowah  35903     1000 Goodyear Ave
# 4  Electric Utility    Parrish      Walker  35580       460 Gorgas Road
#
#       PrimSource                  ...                   Wind_MW  Geo_MW  \
# 0  hydroelectric                  ...                       0.0     NaN
# 1           coal                  ...                       0.0     NaN
# 2  hydroelectric                  ...                       0.0     NaN
# 3    natural gas                  ...                       0.0     NaN
# 4           coal                  ...                       0.0     NaN
#
#    Other_MW                               source_des  \
# 0       NaN                    Hydroelectric = 56 MW
# 1       NaN  Coal = 1088.5 MW, Natural Gas = 1072 MW
# 2       NaN                 Hydroelectric = 225.9 MW
# 3       NaN                     Natural Gas = 130 MW
# 4       NaN                           Coal = 1034 MW
#
#                                            tech_desc  \
# 0                         Conventional Hydroelectric
# 1  Conventional Steam Coal; Natural Gas Fired Com...
# 2                         Conventional Hydroelectric
# 3                          Natural Gas Steam Turbine
# 4                            Conventional Steam Coal
#
#                           Source  Period   Latitude  Longitude  \
# 0  EIA-860, EIA-860M and EIA-923  201607  33.458665 -87.356823
# 1  EIA-860, EIA-860M and EIA-923  201607  31.006900 -88.010300
# 2  EIA-860, EIA-860M and EIA-923  201607  32.583889 -86.283056
# 3  EIA-860, EIA-860M and EIA-923  201607  34.012800 -85.970800
# 4  EIA-860, EIA-860M and EIA-923  201607  33.644344 -87.196486
#
#                                geometry
# 0  POINT (-87.35682299999999 33.458665)
# 1              POINT (-88.0103 31.0069)
# 2          POINT (-86.283056 32.583889)
# 3              POINT (-85.9708 34.0128)
# 4  POINT (-87.19648599999999 33.644344)
#
# [5 rows x 29 columns]

# %% [markdown]
# # Which states have the most renewable plants, as a % of total plants? (include hydro, wind, solar)

# %%
df.columns
# Out:
# Index(['Plant_Code', 'Plant_Name', 'Utility_Na', 'Utility_ID', 'sector_nam',
#        'City', 'County', 'Zip', 'Street_Add', 'PrimSource', 'Total_MW',
#        'Coal_MW', 'NG_MW', 'Crude_MW', 'Bio_MW', 'Hydro_MW', 'HydroPS_MW',
#        'Nuclear_MW', 'Solar_MW', 'Wind_MW', 'Geo_MW', 'Other_MW', 'source_des',
#        'tech_desc', 'Source', 'Period', 'Latitude', 'Longitude', 'geometry'],
#       dtype='object')

# %% [markdown]
# ## Which power plants are within 75 miles of New York City?
